# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Raw Data 폴더 이전
#[D9&10] 데이터시각화 프로젝트_2조/Data/raw data/스쿨존내어린이 사고다발지역정보.csv
schzone = pd.read_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_2조/Data/raw data/스쿨존내어린이 사고다발지역정보.csv', encoding='CP949')

# %%
schzone
# Out:
#      사고다발지FID  ...                                            다발지역폴리곤
# 0       99210  ...  {"type":"Polygon","coordinates":[[[127.002009,...
# 1       99846  ...  {"type":"Polygon","coordinates":[[[127.0381354...
# 2       98904  ...  {"type":"Polygon","coordinates":[[[127.0169658...
# 3       99206  ...  {"type":"Polygon","coordinates":[[[127.0619982...
# 4       99209  ...  {"type":"Polygon","coordinates":[[[127.0268336...
# ..        ...  ...                                                ...
# 346   6671695  ...  {"type":"Polygon","coordinates":[[[129.2319722...
# 347   6671664  ...  {"type":"Polygon","coordinates":[[[128.6956076...
# 348   6671665  ...  {"type":"Polygon","coordinates":[[[127.9123601...
# 349   6671669  ...  {"type":"Polygon","coordinates":[[[126.4046815...
# 350   6671694  ...  {"type":"Polygon","coordinates":[[[126.4798034...
#
# [351 rows x 15 columns]

# %%
schzone = pd.read_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_2조/Data/raw data/스쿨존내어린이 사고다발지역정보.csv', index_col=0)
schzone.drop(['Unnamed: 0'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-29-b5a9bfb91e31> in <module>()
# ----> 1 schzone = pd.read_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_2조/Data/raw data/스쿨존내어린이 사고다발지역정보.csv', index_col=0)
#       2 schzone.drop(['Unnamed: 0'], axis = 1, inplace = True)
#
# ...

# %%
schzone.head()
# Out:
#    사고다발지FID  ...                                            다발지역폴리곤
# 0     99210  ...  {"type":"Polygon","coordinates":[[[127.002009,...
# 1     99846  ...  {"type":"Polygon","coordinates":[[[127.0381354...
# 2     98904  ...  {"type":"Polygon","coordinates":[[[127.0169658...
# 3     99206  ...  {"type":"Polygon","coordinates":[[[127.0619982...
# 4     99209  ...  {"type":"Polygon","coordinates":[[[127.0268336...
#
# [5 rows x 15 columns]

# %%
schzone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   사고다발지FID  351 non-null    int64
#  1   사고다발지ID   351 non-null    int64
#  2   법정동코드     351 non-null    int64
#  3   지점코드      351 non-null    int64
#  4   시도시군구명    351 non-null    object
#  5   지점명       351 non-null    object
#  6   발생건수      351 non-null    int64
#  7   사상자수      351 non-null    int64
#  8   사망자수      351 non-null    int64
#  9   중상자수      351 non-null    int64
#  10  경상자수      351 non-null    int64
#  11  부상신고자수    351 non-null    int64
#  12  경도        351 non-null    float64
#  13  위도        351 non-null    float64
#  14  다발지역폴리곤   351 non-null    object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 41.3+ KB

# %%
schzone['시도시군구명'].unique()
# Out:
# array(['서울특별시 종로구1', '서울특별시 성북구1', '서울특별시 성북구2', '서울특별시 성북구3',
#        '서울특별시 도봉구1', '서울특별시 노원구1', '서울특별시 구로구1', '서울특별시 구로구2',
#        '서울특별시 송파구1', '부산광역시 남구1', '부산광역시 남구2', '부산광역시 해운대구1',
#        '부산광역시 금정구1', '대구광역시 달서구1', '광주광역시 북구1', '광주광역시 광산구1',
#        '대전광역시 대덕구1', '경기도 수원시 영통구1', '경기도 의정부시1', '경기도 부천시 원미구1',
#        '경기도 평택시1', '경기도 안산시 단원구1', '경기도 안산시 단원구2', '경기도 남양주시1',
#        '강원도 동해시1', '전라남도 광양시1', '경상북도 구미시1', '경상북도 예천군1', '경상남도 창원시 진해구1',
#        '경상남도 사천시1', '경상남도 김해시1', '경상남도 거제시1', '경상남도 거창군1', '제주특별자치도 제주시1',
#        '제주특별자치도 제주시2', '서울특별시 동대문구1', '서울특별시 서대문구1', '서울특별시 동작구1',
#        '부산광역시 동래구1', '대전광역시 동구1', '대전광역시 중구1', '울산광역시 북구1', '울산광역시 북구2',
#        '경기도 부천시 소사구1', '경기도 광주시1', '경기도 광주시2', '경기도 포천시1', '강원도 강릉시1',
#        '충청북도 청주시 흥덕구1', '충청북도 청주시 흥덕구2', '충청북도 진천군1', '전라남도 순천시1',
#        '전라남도 고흥군1', '경상북도 경산시1', '경상북도 칠곡군1', '경상남도 창원시 의창구1',
#        '제주특별자치도 서귀포시1', '서울특별시 은평구1', '서울특별시 은평구2', '서울특별시 양천구1',
# ...

# %%
schzone['시도시군구명'].unique()
schzone.loc[schzone['시도시군구명'].str.contains('서울'), '지역']='서울'

# %%
schzone[schzone['지역']=='서울']['시도시군구명'].unique()
# Out:
# array(['서울특별시 종로구1', '서울특별시 성북구1', '서울특별시 성북구2', '서울특별시 성북구3',
#        '서울특별시 도봉구1', '서울특별시 노원구1', '서울특별시 구로구1', '서울특별시 구로구2',
#        '서울특별시 송파구1', '서울특별시 동대문구1', '서울특별시 서대문구1', '서울특별시 동작구1',
#        '서울특별시 은평구1', '서울특별시 은평구2', '서울특별시 양천구1', '서울특별시 동작구2',
#        '서울특별시 중랑구1', '서울특별시 금천구1', '서울특별시 강북구1', '서울특별시 관악구1',
#        '서울특별시 관악구2', '서울특별시 강동구1', '서울특별시 강서구1', '서울특별시 강남구1',
#        '서울특별시 강남구2', '서울특별시 강남구3', '서울특별시 중랑구2', '서울특별시 서초구1',
#        '서울특별시 강서구2', '서울특별시 강서구3', '서울특별시 광진구1'], dtype=object)

# %%
schzone['시도시군구명'] = schzone['시도시군구명'].str[:-1]
schzone.head(5)
# Out:
#    사고다발지FID  사고다발지ID  ...                                            다발지역폴리곤  지역
# 0     99210  2013060  ...  {"type":"Polygon","coordinates":[[[127.002009,...  서울
# 1     99846  2013060  ...  {"type":"Polygon","coordinates":[[[127.0381354...  서울
# 2     98904  2013060  ...  {"type":"Polygon","coordinates":[[[127.0169658...  서울
# 3     99206  2013060  ...  {"type":"Polygon","coordinates":[[[127.0619982...  서울
# 4     99209  2013060  ...  {"type":"Polygon","coordinates":[[[127.0268336...  서울
#
# [5 rows x 16 columns]

# %%
schzone['행정구역'] = schzone['시도시군구명'].str.strip("서울특별시").str.strip()
del schzone['시도시군구명']
schzone
# Out:
#      사고다발지FID  사고다발지ID  ...   지역        행정구역
# 0       99210  2013060  ...   서울         종로구
# 1       99846  2013060  ...   서울         성북구
# 2       98904  2013060  ...   서울         성북구
# 3       99206  2013060  ...   서울         성북구
# 4       99209  2013060  ...   서울         도봉구
# ..        ...      ...  ...  ...         ...
# 346   6671695  2021018  ...  NaN     경상북도 경주
# 347   6671664  2021018  ...  NaN     경상북도 안동
# 348   6671665  2021018  ...  NaN    경상남도 거창군
# 349   6671669  2021018  ...  NaN  제주특별자치도 제주
# 350   6671694  2021018  ...  NaN  제주특별자치도 제주
#
# [351 rows x 16 columns]

# %%
schzone['사고다발지ID']= schzone['사고다발지ID'].apply(str)
schzone['연도'] = schzone['사고다발지ID'].str[:-3]
del schzone['사고다발지ID']
schzone
# Out:
#      사고다발지FID       법정동코드      지점코드  ...   지역        행정구역    연도
# 0       99210  1111016900  11110001  ...   서울         종로구  2013
# 1       99846  1129013500  11290001  ...   서울         성북구  2013
# 2       98904  1129011000  11290002  ...   서울         성북구  2013
# 3       99206  1129013900  11290003  ...   서울         성북구  2013
# 4       99209  1132010500  11320001  ...   서울         도봉구  2013
# ..        ...         ...       ...  ...  ...         ...   ...
# 346   6671695  4713012600  47130001  ...  NaN     경상북도 경주  2021
# 347   6671664  4717013300  47170001  ...  NaN     경상북도 안동  2021
# 348   6671665  4888025000  48880001  ...  NaN    경상남도 거창군  2021
# 349   6671669  5011025300  50110001  ...  NaN  제주특별자치도 제주  2021
# 350   6671694  5011013700  50110002  ...  NaN  제주특별자치도 제주  2021
#
# [351 rows x 16 columns]

# %%
schzone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   사고다발지FID  351 non-null    int64
#  1   법정동코드     351 non-null    int64
#  2   지점코드      351 non-null    int64
#  3   지점명       351 non-null    object
#  4   발생건수      351 non-null    int64
#  5   사상자수      351 non-null    int64
#  6   사망자수      351 non-null    int64
#  7   중상자수      351 non-null    int64
#  8   경상자수      351 non-null    int64
#  9   부상신고자수    351 non-null    int64
#  10  경도        351 non-null    float64
#  11  위도        351 non-null    float64
#  12  다발지역폴리곤   351 non-null    object
#  13  지역        62 non-null     object
#  14  행정구역      351 non-null    object
#  15  연도        351 non-null    object
# dtypes: float64(2), int64(9), object(5)
# memory usage: 44.0+ KB

# %%
schzone['연도'] = schzone['연도'].apply(pd.to_numeric)
schzone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   사고다발지FID  351 non-null    int64
#  1   법정동코드     351 non-null    int64
#  2   지점코드      351 non-null    int64
#  3   지점명       351 non-null    object
#  4   발생건수      351 non-null    int64
#  5   사상자수      351 non-null    int64
#  6   사망자수      351 non-null    int64
#  7   중상자수      351 non-null    int64
#  8   경상자수      351 non-null    int64
#  9   부상신고자수    351 non-null    int64
#  10  경도        351 non-null    float64
#  11  위도        351 non-null    float64
#  12  다발지역폴리곤   351 non-null    object
#  13  지역        62 non-null     object
#  14  행정구역      351 non-null    object
#  15  연도        351 non-null    int64
# dtypes: float64(2), int64(10), object(4)
# memory usage: 44.0+ KB

# %%
# 수정 220117-01
#사고다발지ID->연도로 변경, 지점명, 행정구역, 지점코드, 위도, 경도, 발생건수, 사상자수, 사망자수, 중상자수, 경상자수, 부상신고자수, 다발지역 폴리곤

schzone = schzone[['사고다발지FID', '연도', '법정동코드', '지점코드', '행정구역', '지점명', '발생건수', '사상자수', '사망자수', '중상자수', '경상자수', '부상신고자수','경도', '위도', '다발지역폴리곤', '지역']]
schzone
# Out:
#      사고다발지FID    연도  ...                                            다발지역폴리곤   지역
# 0       99210  2013  ...  {"type":"Polygon","coordinates":[[[127.002009,...   서울
# 1       99846  2013  ...  {"type":"Polygon","coordinates":[[[127.0381354...   서울
# 2       98904  2013  ...  {"type":"Polygon","coordinates":[[[127.0169658...   서울
# 3       99206  2013  ...  {"type":"Polygon","coordinates":[[[127.0619982...   서울
# 4       99209  2013  ...  {"type":"Polygon","coordinates":[[[127.0268336...   서울
# ..        ...   ...  ...                                                ...  ...
# 346   6671695  2021  ...  {"type":"Polygon","coordinates":[[[129.2319722...  NaN
# 347   6671664  2021  ...  {"type":"Polygon","coordinates":[[[128.6956076...  NaN
# 348   6671665  2021  ...  {"type":"Polygon","coordinates":[[[127.9123601...  NaN
# 349   6671669  2021  ...  {"type":"Polygon","coordinates":[[[126.4046815...  NaN
# 350   6671694  2021  ...  {"type":"Polygon","coordinates":[[[126.4798034...  NaN
#
# ...

# %%
# 수정 220117-02
# 2016-2020년까지만 반영 
# 복합조건 필터링

schz = schzone[(schzone['연도'] >= 2016) & (schzone['연도'] <= 2020)]
schz
# Out:
#      사고다발지FID    연도  ...                                            다발지역폴리곤   지역
# 105   6141105  2016  ...  {"type":"Polygon","coordinates":[[[127.0777089...   서울
# 106   6107962  2016  ...  {"type":"Polygon","coordinates":[[[127.0509790...   서울
# 107   6107948  2016  ...  {"type":"Polygon","coordinates":[[[127.0437176...   서울
# 108   6139185  2016  ...  {"type":"Polygon","coordinates":[[[126.9027531...   서울
# 109   6107952  2016  ...  {"type":"Polygon","coordinates":[[[129.0691591...  NaN
# ..        ...   ...  ...                                                ...  ...
# 310   6597146  2020  ...  {"type":"Polygon","coordinates":[[[127.5308488...  NaN
# 311   6596515  2020  ...  {"type":"Polygon","coordinates":[[[128.3344687...  NaN
# 312   6596516  2020  ...  {"type":"Polygon","coordinates":[[[128.0897481...  NaN
# 313   6596517  2020  ...  {"type":"Polygon","coordinates":[[[128.6463690...  NaN
# 314   6596519  2020  ...  {"type":"Polygon","coordinates":[[[126.5797757...  NaN
#
# ...

# %%
schz0 = schz[schz['지역']=='서울']
sort = ['법정동코드', '지점코드', '연도', '행정구역', '지점명','발생건수',	'사상자수',	'사망자수',	'중상자수',	'경상자수',	'부상신고자수', '위도', '경도', '다발지역폴리곤']
schz1 = schz[schz['지역']=='서울']
schz1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 105 to 282
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   사고다발지FID  38 non-null     int64
#  1   연도        38 non-null     int64
#  2   법정동코드     38 non-null     int64
#  3   지점코드      38 non-null     int64
#  4   행정구역      38 non-null     object
#  5   지점명       38 non-null     object
#  6   발생건수      38 non-null     int64
#  7   사상자수      38 non-null     int64
#  8   사망자수      38 non-null     int64
#  9   중상자수      38 non-null     int64
#  10  경상자수      38 non-null     int64
#  11  부상신고자수    38 non-null     int64
#  12  경도        38 non-null     float64
#  13  위도        38 non-null     float64
#  14  다발지역폴리곤   38 non-null     object
#  15  지역        38 non-null     object
# dtypes: float64(2), int64(10), object(4)
# memory usage: 5.0+ KB

# %%
schz.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
schz1.reset_index(inplace=True)
schz1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-9aeb7726d050> in <module>()
# ----> 1 schz1.reset_index(inplace=True)
#       2 schz1
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4857                 # to ndarray and maybe infer different dtype
#    4858                 level_values = _maybe_casted_values(lev, lab)
# -> 4859                 new_obj.insert(0, name, level_values)
#    4860
#    4861         new_obj.index = new_index
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3626         self._ensure_valid_index(value)
#    3627         value = self._sanitize_column(column, value, broadcast=False)
# -> 3628         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3629
# ...

# %%
schz1.to_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_2조/김현우/schz v04(최종).csv')
