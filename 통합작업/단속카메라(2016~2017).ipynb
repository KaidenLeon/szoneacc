# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import folium
import seaborn as sns

# %%
from matplotlib import font_manager, rcParams
# !apt-get install fonts-nanum*
rcParams['font.family'] = 'NanumGothicCoding'
rcParams['axes.unicode_minus'] = False
font_manager._rebuild()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'fonts-nanum-eco' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-gothic-light' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-coding' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-extra' for glob 'fonts-nanum*'
# fonts-nanum is already the newest version (20170925-1).
# fonts-nanum-coding is already the newest version (2.5-1).
# fonts-nanum-eco is already the newest version (1.000-6).
# fonts-nanum-extra is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
svcam = pd.read_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_2조/Data/단속카메라(16~20).csv', index_col=False)
svcam
# Out:
#      Unnamed: 0  index 무인교통단속카메라관리번호    시도명  ...     데이터기준일자   제공기관코드      제공기관명  지역
# 0             2    704            43  서울특별시  ...  2021-11-03  3080000  서울특별시 강북구  서울
# 1             3    705            44  서울특별시  ...  2021-11-03  3080000  서울특별시 강북구  서울
# 2             4    706            45  서울특별시  ...  2021-11-03  3080000  서울특별시 강북구  서울
# 3            23    750            35  서울특별시  ...  2021-11-03  3080000  서울특별시 강북구  서울
# 4            24    751            36  서울특별시  ...  2021-11-03  3080000  서울특별시 강북구  서울
# ..          ...    ...           ...    ...  ...         ...      ...        ...  ..
# 316        1762  19070            44  서울특별시  ...  2021-06-23  3040000  서울특별시 광진구  서울
# 317        1763  19071            45  서울특별시  ...  2021-06-23  3040000  서울특별시 광진구  서울
# 318        1791  19132             4  서울특별시  ...  2021-06-23  3040000  서울특별시 광진구  서울
# 319        1792  19133            36  서울특별시  ...  2021-06-23  3040000  서울특별시 광진구  서울
# ...

# %%
plt.figure( figsize=(30, 10) )
sns.countplot( data=svcam, x='설치연도', hue='시군구명', palette='Paired' )
plt.legend(bbox_to_anchor = (1,1))
plt.show()

# %%
svcam[ svcam['시군구명'] == '성북구'].plot( kind='bar', x='설치연도')

# %%
uaz = pd.read_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_2조/Data/통합 다발지역.csv', index_col=False)
uaz
# Out:
#        연도   구분  ...      지점코드                                            다발지역폴리곤
# 0    2016   일반  ...  11170001  {"type":"Polygon","coordinates":[[[126.9748069...
# 1    2016   일반  ...  11230001  {"type":"Polygon","coordinates":[[[127.0699180...
# 2    2016   일반  ...  11260001  {"type":"Polygon","coordinates":[[[127.0967298...
# 3    2016   일반  ...  11260002  {"type":"Polygon","coordinates":[[[127.0763544...
# 4    2016   일반  ...  11290001  {"type":"Polygon","coordinates":[[[127.0381721...
# ..    ...  ...  ...       ...                                                ...
# 100  2020  스쿨존  ...  11500001  {"type":"Polygon","coordinates":[[[126.8493184...
# 101  2020  스쿨존  ...  11500002  {"type":"Polygon","coordinates":[[[126.8550183...
# 102  2020  스쿨존  ...  11500003  {"type":"Polygon","coordinates":[[[126.8160709...
# 103  2020  스쿨존  ...  11530001  {"type":"Polygon","coordinates":[[[126.8859187...
# 104  2020  스쿨존  ...  11530002  {"type":"Polygon","coordinates":[[[126.8450552...
#
# ...

# %%
uaz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   연도       105 non-null    int64
#  1   구분       105 non-null    object
#  2   행정구역     105 non-null    object
#  3   지점명      105 non-null    object
#  4   발생건수     105 non-null    int64
#  5   사상자수     105 non-null    int64
#  6   사망자수     105 non-null    int64
#  7   중상자수     105 non-null    int64
#  8   경상자수     105 non-null    int64
#  9   부상신고자수   105 non-null    int64
#  10  ARI      105 non-null    float64
#  11  지점코드     105 non-null    int64
#  12  다발지역폴리곤  105 non-null    object
# dtypes: float64(1), int64(8), object(4)
# memory usage: 10.8+ KB

# %%
uaz.columns
# Out:
# Index(['연도', '구분', '행정구역', '지점명', '발생건수', '사상자수', '사망자수', '중상자수', '경상자수',
#        '부상신고자수', 'ARI', '지점코드', '다발지역폴리곤'],
#       dtype='object')

# %%
plt.figure( figsize=(30, 10) )
sns.barplot(data=uaz, x='연도', y='사상자수', hue='행정구역', palette='Paired' )
plt.legend(bbox_to_anchor = (1,1))
plt.show()
