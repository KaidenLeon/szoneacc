# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Raw Data 폴더 이전
#[D9&10] 데이터시각화 프로젝트_2조/Data/raw data/전국무인교통단속카메라표준데이터.csv
svcam = pd.read_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_2조/Data/raw data/전국무인교통단속카메라표준데이터.csv', encoding='CP949')

# %%
svcam
# Out:
#       무인교통단속카메라관리번호  시도명 시군구명  ...     데이터기준일자   제공기관코드         제공기관명
# 0             F9486  경기도  시흥시  ...  2021-10-13  1337000  경찰청 경기도남부경찰청
# 1             F9487  경기도  시흥시  ...  2021-10-13  1337000  경찰청 경기도남부경찰청
# 2             F9488  경기도  안산시  ...  2021-10-13  1337000  경찰청 경기도남부경찰청
# 3             F9489  경기도  안산시  ...  2021-10-13  1337000  경찰청 경기도남부경찰청
# 4             F9490  경기도  안성시  ...  2021-10-13  1337000  경찰청 경기도남부경찰청
# ...             ...  ...  ...  ...         ...      ...           ...
# 19576        P-6109  경기도  고양시  ...  2021-12-07  3940000       경기도 고양시
# 19577        P-6110  경기도  고양시  ...  2021-12-07  3940000       경기도 고양시
# 19578        P-6111  경기도  고양시  ...  2021-12-07  3940000       경기도 고양시
# 19579        P-6112  경기도  고양시  ...  2021-12-07  3940000       경기도 고양시
# 19580        P-6201  경기도  고양시  ...  2021-12-07  3940000       경기도 고양시
#
# [19581 rows x 23 columns]

# %%
svcam.head()
# Out:
#   무인교통단속카메라관리번호  시도명 시군구명  ...     데이터기준일자   제공기관코드         제공기관명
# 0         F9486  경기도  시흥시  ...  2021-10-13  1337000  경찰청 경기도남부경찰청
# 1         F9487  경기도  시흥시  ...  2021-10-13  1337000  경찰청 경기도남부경찰청
# 2         F9488  경기도  안산시  ...  2021-10-13  1337000  경찰청 경기도남부경찰청
# 3         F9489  경기도  안산시  ...  2021-10-13  1337000  경찰청 경기도남부경찰청
# 4         F9490  경기도  안성시  ...  2021-10-13  1337000  경찰청 경기도남부경찰청
#
# [5 rows x 23 columns]

# %%
svcam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19581 entries, 0 to 19580
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   무인교통단속카메라관리번호  19581 non-null  object
#  1   시도명            19581 non-null  object
#  2   시군구명           19581 non-null  object
#  3   도로종류           19581 non-null  object
#  4   도로노선번호         14094 non-null  object
#  5   도로노선명          19581 non-null  object
#  6   도로노선방향         18651 non-null  float64
#  7   소재지도로명주소       10150 non-null  object
#  8   소재지지번주소        18085 non-null  object
#  9   위도             19355 non-null  float64
#  10  경도             19340 non-null  float64
#  11  설치장소           19581 non-null  object
#  12  단속구분           19581 non-null  object
#  13  제한속도           19581 non-null  int64
#  14  단속구간위치구분       401 non-null    float64
#  15  과속단속구간길이       469 non-null    float64
#  16  보호구역구분         4904 non-null   float64
# ...

# %%
svcam['시군구명'].unique()
# Out:
# array(['시흥시', '안산시', '안성시', '수원시', '광명시', '안양시', '이천시', '부천시', '용인시',
#        '평택시', '화성시', '김포시', '양평군', '의왕시', '성남시', '동두천시', '과천시', '여주시',
#        '광주시', '수성', '달서', '성서', '강북', '중부', '서부', '북부', '동부', '달성', '강릉시',
#        '강진군', '남동구', '강북구', '서북구', '파주시', '중구', '장성군', '거창군', '서천군',
#        '금산군', '청양군', '예산군', '태안군', '아산시', '보령시', '홍성군', '공주시', '서산시',
#        '천안시', '없음', '당진시', '논산시', '계룡시', '부여군', '울진군', '영동군', '군포시',
#        '진도군', '곡성군', '부산진구', '밀양시', '예천군', '의창구', '완주군', '덕진구', '익산시',
#        '완산구', '김제시', '진안군', '임실군', '남원시', '정읍시', '고창군', '장수군', '군산시',
#        '남구', '제주시', '고속도로', '정선군', '춘천시', '인제군', '원주시', '안산시 단원구', '무주군',
#        '부안군', '순창군', '유성구', '서구', '미추홀구', '연수구', '옹진', '계양구', '강화군',
#        '부평구', '충주시', '칠곡', '동구', '울진', '구미', '남부', '서귀포시', '강동구', '횡성군',
#        '속초시', '고성군', '양양군', '영월군', '홍천군', '평창군', '태백시', '대덕구', '수영구',
#        '북구', '강서구', '사하구', '기장군', '금정구', '동래구', '사상구', '연제구', '영도구',
# ...

# %%
svcam['시도명'].unique()
svcam.loc[svcam['시도명'].str.contains('서울'), '지역']='서울'

# %%
svcam[svcam['지역']=='서울']['시도명'].unique()
svcam.head(5)
# Out:
#   무인교통단속카메라관리번호  시도명 시군구명  도로종류  ...     데이터기준일자   제공기관코드         제공기관명   지역
# 0         F9486  경기도  시흥시    시도  ...  2021-10-13  1337000  경찰청 경기도남부경찰청  NaN
# 1         F9487  경기도  시흥시    시도  ...  2021-10-13  1337000  경찰청 경기도남부경찰청  NaN
# 2         F9488  경기도  안산시  일반국도  ...  2021-10-13  1337000  경찰청 경기도남부경찰청  NaN
# 3         F9489  경기도  안산시    시도  ...  2021-10-13  1337000  경찰청 경기도남부경찰청  NaN
# 4         F9490  경기도  안성시    시도  ...  2021-10-13  1337000  경찰청 경기도남부경찰청  NaN
#
# [5 rows x 24 columns]

# %%
svcam['설치연도'] =svcam['설치연도'].astype(str)
svcam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19581 entries, 0 to 19580
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   무인교통단속카메라관리번호  19581 non-null  object
#  1   시도명            19581 non-null  object
#  2   시군구명           19581 non-null  object
#  3   도로종류           19581 non-null  object
#  4   도로노선번호         14094 non-null  object
#  5   도로노선명          19581 non-null  object
#  6   도로노선방향         18651 non-null  float64
#  7   소재지도로명주소       10150 non-null  object
#  8   소재지지번주소        18085 non-null  object
#  9   위도             19355 non-null  float64
#  10  경도             19340 non-null  float64
#  11  설치장소           19581 non-null  object
#  12  단속구분           19581 non-null  object
#  13  제한속도           19581 non-null  int64
#  14  단속구간위치구분       401 non-null    float64
#  15  과속단속구간길이       469 non-null    float64
#  16  보호구역구분         4904 non-null   float64
# ...

# %%
# 50% 이상 노후 단속 카메라의 경우 설치연도 결측치로 나타나 측정 불가

svcam['설치연도'] = svcam['설치연도'].apply(pd.to_numeric)
svcam.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "nan"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-911132c9959f> in <module>()
# ----> 1 svcam['설치연도'] = svcam['설치연도'].apply(pd.to_numeric)
#       2 svcam.info()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4211             else:
#    4212                 values = self.astype(object)._values
# -> 4213                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4214
#    4215         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ...

# %%
svc = svcam[(svcam['설치연도'] >= 2016) & (schzone['설치연도'] <= 2020)]
svc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-8b8cd4b89b1b> in <module>()
# ----> 1 svc = svcam[(svcam['설치연도'] >= 2016) & (schzone['설치연도'] <= 2020)]
#       2 svc
#
# NameError: name 'schzone' is not defined

# %%
svc1 = svcam[svcam['지역']=='서울']
svc1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1794 entries, 277 to 19134
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   무인교통단속카메라관리번호  1794 non-null   object
#  1   시도명            1794 non-null   object
#  2   시군구명           1794 non-null   object
#  3   도로종류           1794 non-null   object
#  4   도로노선번호         1060 non-null   object
#  5   도로노선명          1794 non-null   object
#  6   도로노선방향         1794 non-null   float64
#  7   소재지도로명주소       1767 non-null   object
#  8   소재지지번주소        1354 non-null   object
#  9   위도             1793 non-null   float64
#  10  경도             1794 non-null   float64
#  11  설치장소           1794 non-null   object
#  12  단속구분           1794 non-null   object
#  13  제한속도           1794 non-null   int64
#  14  단속구간위치구분       0 non-null      float64
#  15  과속단속구간길이       70 non-null     float64
#  16  보호구역구분         861 non-null    float64
# ...

# %%
svc1.reset_index(inplace=True)
svc1
# Out:
#       index 무인교통단속카메라관리번호    시도명 시군구명  ...     데이터기준일자   제공기관코드      제공기관명  지역
# 0       277            34  서울특별시  강북구  ...  2021-11-03  3080000  서울특별시 강북구  서울
# 1       402            33  서울특별시  강북구  ...  2021-11-03  3080000  서울특별시 강북구  서울
# 2       704            43  서울특별시  강북구  ...  2021-11-03  3080000  서울특별시 강북구  서울
# 3       705            44  서울특별시  강북구  ...  2021-11-03  3080000  서울특별시 강북구  서울
# 4       706            45  서울특별시  강북구  ...  2021-11-03  3080000  서울특별시 강북구  서울
# ...     ...           ...    ...  ...  ...         ...      ...        ...  ..
# 1789  19130            24  서울특별시  광진구  ...  2021-06-23  3040000  서울특별시 광진구  서울
# 1790  19131             6  서울특별시  광진구  ...  2021-06-23  3040000  서울특별시 광진구  서울
# 1791  19132             4  서울특별시  광진구  ...  2021-06-23  3040000  서울특별시 광진구  서울
# 1792  19133            36  서울특별시  광진구  ...  2021-06-23  3040000  서울특별시 광진구  서울
# 1793  19134            37  서울특별시  광진구  ...  2021-06-23  3040000  서울특별시 광진구  서울
#
# ...

# %%
svc1.to_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_2조/김현우/svc v01(최종).csv')

# %%
svc2 = pd.read_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_2조/김현우/svc v01(최종).csv',index_col=0)

# %%
svc2
# Out:
#       index 무인교통단속카메라관리번호    시도명 시군구명  ...     데이터기준일자   제공기관코드      제공기관명  지역
# 0       277            34  서울특별시  강북구  ...  2021-11-03  3080000  서울특별시 강북구  서울
# 1       402            33  서울특별시  강북구  ...  2021-11-03  3080000  서울특별시 강북구  서울
# 2       704            43  서울특별시  강북구  ...  2021-11-03  3080000  서울특별시 강북구  서울
# 3       705            44  서울특별시  강북구  ...  2021-11-03  3080000  서울특별시 강북구  서울
# 4       706            45  서울특별시  강북구  ...  2021-11-03  3080000  서울특별시 강북구  서울
# ...     ...           ...    ...  ...  ...         ...      ...        ...  ..
# 1789  19130            24  서울특별시  광진구  ...  2021-06-23  3040000  서울특별시 광진구  서울
# 1790  19131             6  서울특별시  광진구  ...  2021-06-23  3040000  서울특별시 광진구  서울
# 1791  19132             4  서울특별시  광진구  ...  2021-06-23  3040000  서울특별시 광진구  서울
# 1792  19133            36  서울특별시  광진구  ...  2021-06-23  3040000  서울특별시 광진구  서울
# 1793  19134            37  서울특별시  광진구  ...  2021-06-23  3040000  서울특별시 광진구  서울
#
# ...

# %%
svc2['보호구역구분'] = svc2['보호구역구분'].astype(str)
svc2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1794 entries, 0 to 1793
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          1794 non-null   int64
#  1   무인교통단속카메라관리번호  1794 non-null   object
#  2   시도명            1794 non-null   object
#  3   시군구명           1794 non-null   object
#  4   도로종류           1794 non-null   object
#  5   도로노선번호         1060 non-null   object
#  6   도로노선명          1794 non-null   object
#  7   도로노선방향         1794 non-null   float64
#  8   소재지도로명주소       1767 non-null   object
#  9   소재지지번주소        1354 non-null   object
#  10  위도             1793 non-null   float64
#  11  경도             1794 non-null   float64
#  12  설치장소           1794 non-null   object
#  13  단속구분           1794 non-null   int64
#  14  제한속도           1794 non-null   int64
#  15  단속구간위치구분       0 non-null      float64
#  16  과속단속구간길이       70 non-null     float64
# ...

# %%
svc2['보호구역구분'].unique()
svc2.loc[svc2['보호구역구분'].str.contains('2'), '보호구역']='어린이'

# %%
svc2.head()
# Out:
#     index 무인교통단속카메라관리번호    시도명 시군구명  ...   제공기관코드      제공기관명  지역  보호구역
# 47   2275          주차58  서울특별시  강동구  ...  3240000  서울특별시 강동구  서울   어린이
# 48   2276          주차59  서울특별시  강동구  ...  3240000  서울특별시 강동구  서울   어린이
# 50   2278          주차61  서울특별시  강동구  ...  3240000  서울특별시 강동구  서울   어린이
# 51   2279          주차62  서울특별시  강동구  ...  3240000  서울특별시 강동구  서울   어린이
# 52   2280          주차63  서울특별시  강동구  ...  3240000  서울특별시 강동구  서울   어린이
#
# [5 rows x 26 columns]
# ...

# %%
svc2 = svc2[svc2['보호구역']=='어린이']
svc2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 208 entries, 47 to 1793
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          208 non-null    int64
#  1   무인교통단속카메라관리번호  208 non-null    object
#  2   시도명            208 non-null    object
#  3   시군구명           208 non-null    object
#  4   도로종류           208 non-null    object
#  5   도로노선번호         126 non-null    object
#  6   도로노선명          208 non-null    object
#  7   도로노선방향         208 non-null    float64
#  8   소재지도로명주소       208 non-null    object
#  9   소재지지번주소        148 non-null    object
#  10  위도             208 non-null    float64
#  11  경도             208 non-null    float64
#  12  설치장소           208 non-null    object
#  13  단속구분           208 non-null    int64
#  14  제한속도           208 non-null    int64
#  15  단속구간위치구분       0 non-null      float64
#  16  과속단속구간길이       14 non-null     float64
# ...

# %%
svc2['보호구역구분'] = svc2['보호구역구분'].apply(pd.to_numeric)
svc2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 208 entries, 47 to 1793
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          208 non-null    int64
#  1   무인교통단속카메라관리번호  208 non-null    object
#  2   시도명            208 non-null    object
#  3   시군구명           208 non-null    object
#  4   도로종류           208 non-null    object
#  5   도로노선번호         126 non-null    object
#  6   도로노선명          208 non-null    object
#  7   도로노선방향         208 non-null    float64
#  8   소재지도로명주소       208 non-null    object
#  9   소재지지번주소        148 non-null    object
#  10  위도             208 non-null    float64
#  11  경도             208 non-null    float64
#  12  설치장소           208 non-null    object
#  13  단속구분           208 non-null    int64
#  14  제한속도           208 non-null    int64
#  15  단속구간위치구분       0 non-null      float64
#  16  과속단속구간길이       14 non-null     float64
# ...

# %%
svc2.reset_index(inplace=True)
svc2
# Out:
#      level_0  index 무인교통단속카메라관리번호    시도명  ...   제공기관코드      제공기관명  지역 보호구역
# 0         47   2275          주차58  서울특별시  ...  3240000  서울특별시 강동구  서울  어린이
# 1         48   2276          주차59  서울특별시  ...  3240000  서울특별시 강동구  서울  어린이
# 2         50   2278          주차61  서울특별시  ...  3240000  서울특별시 강동구  서울  어린이
# 3         51   2279          주차62  서울특별시  ...  3240000  서울특별시 강동구  서울  어린이
# 4         52   2280          주차63  서울특별시  ...  3240000  서울특별시 강동구  서울  어린이
# ..       ...    ...           ...    ...  ...      ...        ...  ..  ...
# 203     1762  19070            44  서울특별시  ...  3040000  서울특별시 광진구  서울  어린이
# 204     1763  19071            45  서울특별시  ...  3040000  서울특별시 광진구  서울  어린이
# 205     1791  19132             4  서울특별시  ...  3040000  서울특별시 광진구  서울  어린이
# 206     1792  19133            36  서울특별시  ...  3040000  서울특별시 광진구  서울  어린이
# 207     1793  19134            37  서울특별시  ...  3040000  서울특별시 광진구  서울  어린이
#
# [208 rows x 27 columns]

# %%
svc2.to_csv('/content/drive/MyDrive/[D9&10] 데이터시각화 프로젝트_2조/김현우/svc(어린이)v01.csv')
